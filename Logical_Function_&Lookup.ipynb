# %% [markdown]
# 1. Write a formula to check if the marks in cell B2 are greater than or equal to 40. If yes, return "Pass" otherwise "Fail".
#
#        -> =IF(B2>=40, "Pass", "Fail")
#
# 2. A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not
#
#        -> =IF(AND(B2>40000, C2>=90%), "Bonus", "No Bonus")
#
# 3. Write a nested IF formula:
# If marks in areB2 ≥ 90 → "A", ≥ 75 → "B", ≥ 50 →  "C", otherwise  "F" .
#
#         -> =IFS(B24>=90, "A",B24>="75","B",B24>=50,"C",B24<"50","FAIL")
#
# 4.4.Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
#      -> > VLOOKUP is used to search a value from the first column of a table and return a matching value from another column.
#
#      =VLOOKUP("E103", A35:C39, 3, FALSE)
#
# 5. A company has set the following commission structure for its sales team: If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
#        -> =VLOOKUP(45000, A46:B50, 2, TRUE)
#
# 6.The HR department maintains the following leave records of employees:onus or not . Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#  If Leaves Taken > Allowed Leaves, display "Exceeded".
#  Otherwise, display "OK"
#
#       ->=IF(B58 > C58, "Exceeded", "OK")
#
# 7. Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
#        -> =INDEX(B66:B69, MATCH("E105", A66:A69, 0))
#
# 8. Use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
#        ->=XLOOKUP("E303", A75:A78, B75:B78)
